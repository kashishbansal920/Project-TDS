# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishbansal920/Project-TDS/blob/main/TDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/users.csv')
data.head()
# Out:
#              login           name          company          location  \
# 0      krishnaik06   Krish C Naik    PANASONIC IIC         Bangalore
# 1  championswimmer    Arnav Gupta        JIOCINEMA  Bangalore, India
# 2    arpitbbhayani  Arpit Bhayani           DICEDB         Bangalore
# 3    manjunath5496    Manjunath.R  MYW3SCHOOLS.COM  Bangalore, India
# 4      tanaypratap   Tanay Pratap           INVACT  Bangalore, India
#
#                      email  hireable  \
# 0    krishnaik06@gmail.com     False
# 1   dev@championswimmer.in      True
# 2                      NaN      True
# 3  manjunath5496@gmail.com     False
# 4      tanay.mit@gmail.com     False
#
#                                                  bio  public_repos  followers  \
# 0  Data Scientist with ML and Deep  Learning expe...           330      30901
# 1  Director of Engineering - @JioCinema ┃\nPast ▶...           351       4661
# 2  Creator of @DiceDB • ex-Google Dataproc, ex-Am...           188       4556
# ...

# %%
bangalore_users = data[data['location'].str.contains('Bangalore', case=False, na=False)]

# Step 5: Sort by Follower Count and Select Top 5
top_bangalore_users = bangalore_users.sort_values(by='followers', ascending=False).head(5)

# Step 6: Display Results
top_usernames = ', '.join(top_bangalore_users['login'].tolist())
print("Top 5 GitHub users in Bangalore by followers:", top_usernames)
# Out:
# Top 5 GitHub users in Bangalore by followers: krishnaik06, championswimmer, arpitbbhayani, manjunath5496, tanaypratap

# %%
bangalore_users = data[data['location'].str.contains('Bangalore', case=False, na=False)]

# Step 5: Sort by `created_at` in Ascending Order and Select Top 5 Earliest Users
earliest_users = bangalore_users.sort_values(by='created_at', ascending=True).head(5)

# Step 6: Display Results in Ascending Order of Registration Date
earliest_usernames = ', '.join(earliest_users['login'].tolist())
print("Earliest 5 GitHub users in Bangalore by registration date:", earliest_usernames)
# Out:
# Earliest 5 GitHub users in Bangalore by registration date: anandology, irfn, jace, abhisek, abhin4v

# %%
repos = pd.read_csv('/content/repositories.csv')
repos.head()
# Out:
#          login                           full_name            created_at  \
# 0  krishnaik06  krishnaik06/Polars-GPU-Engine-Demo  2024-10-28T08:42:45Z
# 1  krishnaik06  krishnaik06/Transformers-Materials  2024-10-19T15:43:30Z
# 2  krishnaik06              krishnaik06/ETLWeather  2024-10-15T10:45:09Z
# 3  krishnaik06                krishnaik06/datasets  2024-10-08T05:16:12Z
# 4  krishnaik06             krishnaik06/testdagshub  2024-10-01T16:57:42Z
#
#    stargazers_count  watchers_count          language  has_projects  has_wiki  \
# 0                 1               1  Jupyter Notebook          True      True
# 1                 9               9               NaN          True      True
# 2                 9               9            Python          True      True
# 3                 3               3               NaN          True      True
# 4                 0               0               NaN          True      True
#
#   license_name
# 0      gpl-3.0
# 1      gpl-3.0
# ...

# %%
repos['license_name'].value_counts().head(3)
# Out:
# license_name
# mit           10582
# apache-2.0     3703
# other          2386
# Name: count, dtype: int64

# %%
data['company'].value_counts().head(1)
# Out:
# company
# GOOGLE    15
# Name: count, dtype: int64

# %%
repos['language'].value_counts().head(1)
# Out:
# language
# JavaScript    8733
# Name: count, dtype: int64

# %%
users_after_2020 = users[users['created_at'] > '2020-01-01']
users_after_2020.head()
# Out:
#            login            name                    company          location  \
# 25        bigint          Bigint                     HEYXYZ  Bangalore, India
# 28   techiescamp     TechiesCamp  TECHIESCAMP BY DEVOPSCUBE         Bangalore
# 30     saadozone  Saad Bin Noman         VANANAM ENTERPRISE         Bangalore
# 43         yua-9   Yusra Pikhwal                  PATAACOPY   Bangalore,india
# 63  keralahacker  Hackwithvyshu             HACK WITH VYSHU        Bangalore
#
#    email  hireable                                                bio  \
# 25   NaN      True                               Creator of @heyxyz 🌸
# 28   NaN     False  Practical DevOps Learning Platform - Follow @t...
# 30   NaN     False  I'm a passionate Full Stack Developer with exp...
# 43   NaN      True  Python Lover || \nDjango is my crush  ||  \nHa...
# 63   NaN     False                    X-BlackHat 🎩 Hacker | Engineer
#
#     public_repos  followers  following            created_at
# ...

# %%
repos_2020 = repos[repos['login'].isin(users_after_2020['login'].tolist())]
repos_2020['language'].value_counts().head()
# Out:
# language
# JavaScript    1677
# HTML           661
# CSS            589
# Python         302
# TypeScript     183
# Name: count, dtype: int64

# %%
avg_stars = repos.groupby('language')['stargazers_count'].mean()
top_lang = avg_stars.idxmax()
top_stars = avg_stars.max()
print(top_lang, top_stars)
# Out:
# Pascal 92.0

# %%
users['leader_strength'] = users['followers'] / (1 + users['following'])
top5_lead = users.sort_values(by='leader_strength', ascending=False).head()
print(','.join(top5_lead['login'].tolist()))
# Out:
# krishnaik06,Hack-with-Github,laxmimerit,tanaypratap,abhishh1

# %%
correlation = users['followers'].corr(users['public_repos'])
correlation
# Out:
# 0.19236479204433807

# %%
import csv
followers = []
public_repos = []
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        followers_count = int(row['followers'])
        public_repos_count = int(row['public_repos'])
        followers.append(followers_count)
        public_repos.append(public_repos_count)
if len(followers) > 1 and len(public_repos) > 1:
    slope, intercept = np.polyfit(public_repos, followers, 1)

    print(f"{slope:.3f}")
else:
    print("Error")
# Out:
# 2.356

# %%
if repos['has_projects'].dtype == 'object':
    repos['has_projects'] = repos['has_projects'].map({'true': True, 'false': False})
if repos['has_wiki'].dtype == 'object':
    repos['has_wiki'] = repos['has_wiki'].map({'true': True, 'false': False})

correlation = repos['has_projects'].corr(repos['has_wiki'])

print(round(correlation, 3))
# Out:
# 0.196

# %%
repos['has_projects'] = repos['has_projects'].astype(bool)
repos['has_wiki'] = repos['has_wiki'].astype(bool)

# Step 5: Calculate Correlation
correlation = repos[['has_projects', 'has_wiki']].corr().iloc[0, 1]
print(f"Correlation between Projects and Wikis enabled: {correlation}")
# Out:
# Correlation between Projects and Wikis enabled: 0.19646444688548087

# %%
hireable_avg_following = users[users['hireable'] == True]['following'].mean()
non_hireable_avg_following = users[users['hireable'] == False]['following'].mean()
difference = hireable_avg_following - non_hireable_avg_following
difference
# Out:
# 61.96572978303749

# %%
import csv
from collections import Counter
from datetime import datetime

weekend_repo_counts = Counter()

with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        created_at = row.get('created_at', '')
        if created_at:
            created_date = datetime.fromisoformat(created_at[:-1])

            if created_date.weekday() in [5, 6]:
                user_login = row['login']
                weekend_repo_counts[user_login] += 1

top_users = weekend_repo_counts.most_common(5)

top_logins = [user[0] for user in top_users]

print(','.join(top_logins))
# Out:
# itaditya,avinassh,sangam14,manjunath5496,championswimmer

# %%
fraction_hierable = users[users['hireable'] == True]['email'].notna().mean()
fraction_non_hierable = users[users['hireable'] == False]['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
diff
# Out:
# 0.19282320243858703

# %%
new_users = users[users['name'].notna()].copy()
new_users['surname'] = new_users['name'].str.split().str[-1].str.strip()
surname_counts = new_users['surname'].value_counts()
max_count = surname_counts.max()
common_surnames = surname_counts[surname_counts == max_count].index.tolist()
common_surnames.sort()
print(','.join(common_surnames))
# Out:
# Singh

# %%
from sklearn.linear_model import LinearRegression

# Assuming your DataFrame is named 'users'
users_with_bio = users[users['bio'].notna()].copy()

# Calculate bio length in words (Unicode words, split by whitespace)
users_with_bio['bio_length'] = users_with_bio['bio'].apply(lambda x: len(x.split()))

# Prepare data for regression
X = users_with_bio[['bio_length']]  # Use double brackets for DataFrame
y = users_with_bio['followers']

# Create and fit the linear regression model
lr2 = LinearRegression()
lr2.fit(X, y)

# Print the regression slope (coefficient)
print(f"{lr2.coef_[0]:.3f}")
# Out:
# -0.126

# %%
data = data[data['bio'].notna()]

# Step 4: Calculate Bio Length in Words
data['bio_length'] = data['bio'].apply(lambda x: len(x.split()))

# Step 5: Perform Linear Regression
slope, intercept, r_value, p_value, std_err = stats.linregress(data['bio_length'], data['followers'])

# Step 6: Print the Slope
print(f"Regression slope (followers per word in bio): {slope:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-4e514c633d9c> in <cell line: 7>()
#       5
#       6 # Step 5: Perform Linear Regression
# ----> 7 slope, intercept, r_value, p_value, std_err = stats.linregress(data['bio_length'], data['followers'])
#       8
#       9 # Step 6: Print the Slope
#
# NameError: name 'stats' is not defined

# %%
import pandas as pd
from scipy import stats # Import the stats module from scipy

data = data[data['bio'].notna()]

# Step 4: Calculate Bio Length in Words
data['bio_length'] = data['bio'].apply(lambda x: len(x.split()))

# Step 5: Perform Linear Regression
# Use stats.linregress from the imported scipy.stats module
slope, intercept, r_value, p_value, std_err = stats.linregress(data['bio_length'], data['followers'])

# Step 6: Print the Slope
print(f"Regression slope (followers per word in bio): {slope:.3f}")
# Out:
# Regression slope (followers per word in bio): -0.126

# %%
import pandas as pd
from scipy import stats

# Assuming your DataFrame is named 'data'
# Filter users with bios
users_with_bio = data[data['bio'].notna()].copy()

# Calculate bio length in words (Unicode words, split by whitespace)
users_with_bio['bio_length'] = users_with_bio['bio'].apply(lambda x: len(x.split()))

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(users_with_bio['bio_length'], users_with_bio['followers'])

# Print the regression slope
print(f"{slope:.3f}")
# Out:
# -0.126
